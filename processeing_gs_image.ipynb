# %% [markdown]
# Processing Gray Scale images

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
im = plt.imread(r'/home/arvind/fundamentals-of-computer-vision/my_practice/computer_vision/01_Introduction to images/albert-einstein_gray.jpg')

# %%
type(im)
# Out:
# numpy.ndarray

# %%
im.shape
# Out:
# (949, 728)

# %%
im.dtype
# Out:
# dtype('uint8')

# %%
plt.imshow(im, cmap='gray')

# %%
im
# Out:
# array([[85, 85, 85, ..., 62, 62, 62],
#        [85, 85, 85, ..., 64, 65, 64],
#        [85, 85, 85, ..., 59, 59, 58],
#        ...,
#        [36, 42, 42, ..., 36, 42, 47],
#        [29, 37, 37, ..., 36, 43, 44],
#        [33, 40, 37, ..., 35, 43, 42]], shape=(949, 728), dtype=uint8)

# %%
im[23, 300]
# Out:
# np.uint8(70)

# %%
im2 = im.copy()

# %%
im2[23:300, 40:100] = 255

# %%
plt.imshow(im2, cmap='gray')

# %%
plt.imsave(r'/home/arvind/fundamentals-of-computer-vision/my_practice/computer_vision/01_Introduction to images/albert-einstein_gray_modified_gray.jpg',im2, cmap='gray')
